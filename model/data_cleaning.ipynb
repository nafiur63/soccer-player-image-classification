# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test-dataset/ronaldo (12).jpg')
img.shape
# Out:
# (1152, 2048, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1152, 2048)

# %%
gray
# Out:
# array([[ 78,  76,  75, ..., 118, 117, 117],
#        [ 78,  77,  76, ..., 117, 117, 117],
#        [ 78,  78,  77, ..., 117, 116, 116],
#        ...,
#        [131, 130, 129, ..., 133, 133, 132],
#        [132, 131, 129, ..., 133, 133, 133],
#        [132, 131, 130, ..., 134, 134, 134]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv_haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv_haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[898, 137, 325, 325]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (898, 137, 325, 325)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),5)
face_img
# Out:
# array([[[ 66,  73,  92],
#         [ 64,  71,  90],
#         [ 63,  70,  89],
#         ...,
#         [137, 109, 128],
#         [136, 108, 127],
#         [136, 108, 127]],
#
#        [[ 66,  73,  92],
#         [ 65,  72,  91],
#         [ 64,  71,  90],
#         ...,
#         [136, 108, 127],
#         [136, 108, 127],
#         [136, 108, 127]],
#
#        [[ 66,  73,  92],
#         [ 66,  73,  92],
#         [ 65,  72,  91],
#         ...,
#         [136, 108, 127],
#         [135, 107, 126],
#         [135, 107, 126]],
#
#        ...,
#
#        [[122, 122, 152],
#         [121, 121, 151],
#         [122, 120, 150],
#         ...,
#         [135, 124, 150],
#         [135, 124, 150],
#         [134, 123, 149]],
#
#        [[125, 123, 153],
#         [124, 122, 152],
#         [122, 120, 150],
#         ...,
#         [135, 124, 150],
#         [135, 124, 150],
#         [135, 124, 150]],
#
#        [[125, 123, 153],
#         [124, 122, 152],
#         [123, 121, 151],
#         ...,
#         [136, 125, 151],
#         [136, 125, 151],
#         [136, 125, 151]]], dtype=uint8)

# %%
plt.imshow(face_img)
